# %%
# Import our modules that we are using
import matplotlib.pyplot as plt
import numpy as np

# %%
numsqua = 0.0075**2
print(numsqua)
init = numsqua*4229.5
# Out:
# 5.625e-05

# %%
print(x)
# Out:
# [-1.5, -1.0, -0.5, 0, 0.5, 1.0, 1.5]

# %%
# Create the vectors X and Y
xlist = np.arange(-0.008,0.008,0.0005)
#[-0.01,-0.009,-0.008,-0.007,-0.006,-0.005,-0.004,-0.003,-0.002,-0.001,0.0,0.001,0.002,0.003,0.004,0.005,0.006,0.007,0.008,0.009,0.01]
y1list = []
y2list = []
y3list = []
for i in range(len(xlist)):
    y1 = 4229.3*numsqua - 4229.3*xlist[i]*xlist[i]
    y2 = 25361.7*numsqua - 25361.7*xlist[i]*xlist[i]
    y3 = 45451.8*numsqua - 45451.8*xlist[i]*xlist[i]
    y1list.append(y1)
    y2list.append(y2)
    y3list.append(y3)
# Create the plot
plt.figure(figsize=(15, 3), dpi=80)
plt.subplot(1, 3, 1)
plt.title('a. Flow rate = 620mL/29.5s')
plt.xlim(0.00,0.25)
plt.plot(y1list,xlist)
plt.axhline(y=0.0, color='k', linestyle='--')
plt.xlabel('Velocity (m/s)')
plt.ylabel('r (m)')

plt.subplot(1, 3, 2)
plt.title('b. Flow rate = 900mL/7.14s')
plt.xlim(0.00,1.5)
plt.plot(y2list,xlist)
plt.axhline(y=0.0, color='k', linestyle='--')
plt.xlabel('Velocity (m/s)')

plt.subplot(1, 3, 3)
plt.title('c. Flow rate = 750/3.32s')
plt.xlim(0.00,2.6)
plt.plot(y3list,xlist)
plt.axhline(y=0.0, color='k', linestyle='--')
plt.xlabel('Velocity (m/s)')
plt.savefig('HW2')
plt.show()
